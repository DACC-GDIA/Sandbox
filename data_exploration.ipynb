# %%
import pandas as pd
import numpy as np
import os
import matplotlib

# %%
path = r"INSERT PATH"

# %%
df = pd.read_csv('datasample1.csv')   
df2 = pd.read_csv('datasample_setA.csv')

# %%
df
# Out:
#          1000661944  20090505  U   Toyota    Sienna  2006  Y    20120503  \
# 0        1000873290  20130718  U     Ford    Escape  2005  Y  20170103.0
# 1        1005344304  20141031  U     Ford   Mustang  2003  Y  20151218.0
# 2        1002810245  20120612  U  Porsche   Boxster  2000  N         NaN
# 3        1002327903  20130604  U     Ford    Ranger  1997  N         NaN
# 4        1002283792  20110604  N      BMW  3 Series  2011  Y  20121220.0
# ...             ...       ... ..      ...       ...   ... ..         ...
# 1303855  1007241551  20150123  N     Ford  Explorer  2015  N         NaN
# 1303856  1004986575  20150409  U    Dodge  Ram 1500  2009  Y  20161122.0
# 1303857  1003354543  20130627  N  Hyundai     Azera  2012  N         NaN
# 1303858  1003537976  20111020  U     Jeep  Wrangler  2006  Y  20160429.0
# 1303859  1000499890  20100714  U     Ford    Ranger  1996  N         NaN
#
#          Unleaded Gas  P  201904  2019-04-20  201904_HistoricalData
# ...

# %%
list(df2.columns.values)
df2
# Out:
#         Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3     FORD  \
# 0              NaN         NaN         NaN         NaN     FORD
# 1              NaN         NaN         NaN         NaN     FORD
# 2              NaN         NaN         NaN         NaN     FORD
# 3              NaN         NaN         NaN         NaN     FORD
# 4              NaN         NaN         NaN         NaN  LINCOLN
# ...            ...         ...         ...         ...      ...
# 351509         NaN         NaN         NaN         NaN     FORD
# 351510         NaN         NaN         NaN         NaN     FORD
# 351511         NaN         NaN         NaN         NaN     FORD
# 351512         NaN         NaN         NaN         NaN     FORD
# 351513         NaN         NaN         NaN         NaN     FORD
#
#                 FUSION  1  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0             F-SERIES  0         NaN         NaN         NaN  ...
# ...

# %%
new_data = pd.merge(df, df2, left_on="1000661944", right_on="1004727730", how="outer")
new_data.sample(20)
# Out:
#            1000661944    20090505    U      Toyota               Sienna  \
# 1134361  1.004800e+09  20111119.0    U        Ford                Focus
# 382100   1.003187e+09  20120716.0    N        Ford               Taurus
# 1402479           NaN         NaN  NaN         NaN                  NaN
# 724605   1.005593e+09  20110705.0    U       Lexus                   IS
# 1035817  1.000624e+09  20170613.0    N       Dodge              Journey
# 676454   1.004800e+09  20160120.0    U        Ford      F250 Super Duty
# 713562   1.001559e+09  20160411.0    N       Dodge           Challenger
# 781165   1.002332e+09  20171026.0    U  Land Rover    Range Rover Sport
# 137127   1.002114e+09  20090706.0    N        Ford               Escape
# 280251   1.001346e+09  20170509.0    U      Nissan             Frontier
# 373307   1.007075e+09  20170313.0    U      Nissan                Versa
# 1464452           NaN         NaN  NaN         NaN                  NaN
# ...
